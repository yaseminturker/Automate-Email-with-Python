# %% [markdown]
# # Automate Email with Python
# ![image.png](attachment:image.png)

# %% [markdown]
# # Importing libraries

# %%
import smtplib
import ssl
from email.message import EmailMessage

# %% [markdown]
# # Defining email sender and receiver

# %%
email_sender = 'write_your_e_mail_address' #your e-mail address
email_password = 'write_your_password' # to get a gmail password pls read: https://support.google.com/accounts/answer/185833?hl=en
email_receiver = 'write_receiver_address' #receiver(s) e-mail address(es)

# %% [markdown]
# # Setting the subject and body of the email

# %%
subject = 'Hello!'
body = """
How are you?
"""

# %%
em = EmailMessage()
em['From'] = email_sender
em['To'] = email_receiver
em['Subject'] = subject
em.set_content(body)

# %% [markdown]
# ## Adding SSL (layer of security)

# %%
context = ssl.create_default_context()

# %% [markdown]
# # Logging in and sending the email

# %%
with smtplib.SMTP_SSL('smtp.gmail.com', 465, context=context) as smtp:
    smtp.login(email_sender, email_password)
    smtp.sendmail(email_sender, email_receiver, em.as_string())

# %% [markdown]
# ***Thanks for reading. I hope you enjoy it and that it was helpful to you.***
#
# ***Please don't forget to follow me and give an upvote on***
#
# **[Kaggle](https://www.kaggle.com/yaseminturker) | [GitHub](https://github.com/yaseminturker) | [Linkedin](https://www.linkedin.com/in/yasemin-turker/) ✌️**
